# %% [markdown]
# #### Import necessary libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Read csv and select the stock for which you wanna predict future price

# %%
df = pd.read_csv('prices-split-adjusted.csv')
pg = df[df['symbol'] == 'HAL']  ## change 'HAL' with your choice of stock 
pg
# Out:
#               date symbol       open      close        low       high  \
# 448     2010-01-04    HAL  30.719999  31.250000  30.660000  31.340000
# 916     2010-01-05    HAL  31.280001  31.650000  30.990000  31.830000
# 1384    2010-01-06    HAL  31.740000  32.400002  31.639999  32.590000
# 1852    2010-01-07    HAL  32.310001  32.480000  31.920000  32.520000
# 2320    2010-01-08    HAL  32.950001  34.119999  32.490002  34.139999
# ...            ...    ...        ...        ...        ...        ...
# 848972  2016-12-23    HAL  55.040001  54.840000  54.630001  55.259998
# 849472  2016-12-27    HAL  55.020000  54.910000  54.700001  55.540001
# 849972  2016-12-28    HAL  55.110001  54.299999  54.180000  55.220001
# 850472  2016-12-29    HAL  54.139999  54.040001  53.840000  54.459999
# 850972  2016-12-30    HAL  54.029999  54.090000  53.610001  54.360001
#
#             volume
# 448     11571600.0
# 916     18989700.0
# 1384    15720800.0
# 1852     8993100.0
# 2320    23014600.0
# ...            ...
# 848972   3161500.0
# 849472   3608700.0
# 849972   4759700.0
# 850472   4216800.0
# 850972   4638300.0
#
# [1762 rows x 7 columns]

# %%
pg.drop('symbol', axis = 1,  inplace=True)
pg.drop('open', axis = 1,  inplace=True)
pg.drop('low', axis = 1,  inplace=True)
pg.drop('high', axis = 1,  inplace=True)
pg.drop('volume', axis = 1,  inplace=True)
pg.drop('date', axis = 1,  inplace=True)
# Out:
# /Users/subhamgupta/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# #### At this point we can include different technical indicators like moving averages, bollinger bands, RSI etc, but I found that raw data worked out the best with least RMS
#
# ### I have included "Exponential Moving Average" in another code, you can check it out there

# %%
plt.figure(figsize=(16,8))
plt.plot(pg['close'], label='Close Price history')

# %%
dataset = pg.values
train = dataset[0:1400,:]
valid = dataset[1400:,:]

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) # Normalize the data
scaled_data = scaler.fit_transform(dataset)

# %% [markdown]
# #### Now we set our training data, I will feed the data of last 60 days to predict the new price, you can try your version of code with any other choice for number of days.
#
# #### If you increase the number of days the network will take longer time to learn.
#
# #### I've tried 30 days, 60 days and 90 days, and I have noticed that the rms(root mean square) error do not decrease significantly after 60 days.

# %%
x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# %% [markdown]
# #### The model, 2 dense layers with activation function 'tanh', then an LSTM and finally and output layer.
#
# #### I tried varying the number of layers from single LSTM layer to upto 4 dense layer with different number of nodes in each layer, activation functions like 'relu', 'tanh', 'sigmoid' and their combinations, and found that the following model works the best.
#
# #### I also tried dropout in hope to improve the results but it doesn't work out as I expected.

# %%
model = Sequential()
model.add(Dense(20,activation='tanh'))
model.add(Dense(10,activation='tanh'))
model.add(LSTM(units=50))
model.add(Dense(1))

# %% [markdown]
# #### I tried various optimizers, epoch number and batch size.
#
# #### Adam works very good and fast, loss after 60 epochs never reduced significantly.

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=64, batch_size=128, verbose=1)
# Out:
# Epoch 1/64
# 1340/1340 [==============================] - 4s 3ms/step - loss: 0.1176
# Epoch 2/64
# 1340/1340 [==============================] - 2s 1ms/step - loss: 0.0138
# Epoch 3/64
# 1340/1340 [==============================] - 2s 1ms/step - loss: 0.0084
# Epoch 4/64
# 1340/1340 [==============================] - 2s 2ms/step - loss: 0.0047
# Epoch 5/64
# 1340/1340 [==============================] - 2s 2ms/step - loss: 0.0029
# Epoch 6/64
# 1340/1340 [==============================] - 2s 2ms/step - loss: 0.0017
# Epoch 7/64
# 1340/1340 [==============================] - 2s 2ms/step - loss: 0.0012
# Epoch 8/64
# 1340/1340 [==============================] - 2s 2ms/step - loss: 0.0011
# Epoch 9/64
# 1340/1340 [==============================] - 2s 2ms/step - loss: 0.0011
# Epoch 10/64
# 1340/1340 [==============================] - 2s 2ms/step - loss: 0.0011
# Epoch 11/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 0.0011
# Epoch 12/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 0.0010
# Epoch 13/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 0.0010
# Epoch 14/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 0.0010
# Epoch 15/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 0.0010
# Epoch 16/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 9.8521e-04
# Epoch 17/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 9.7018e-04
# Epoch 18/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 9.5324e-04
# Epoch 19/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 9.3984e-04
# Epoch 20/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 9.3837e-04
# Epoch 21/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 9.1180e-04
# Epoch 22/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 9.0435e-04
# Epoch 23/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 9.0286e-04
# Epoch 24/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 8.8784e-04
# Epoch 25/64
# 1340/1340 [==============================] - 3s 3ms/step - loss: 8.7297e-04
# Epoch 26/64
# 1340/1340 [==============================] - 4s 3ms/step - loss: 8.5204e-04
# Epoch 27/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 8.4088e-04
# Epoch 28/64
# 1340/1340 [==============================] - 4s 3ms/step - loss: 8.3352e-04
# Epoch 29/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 8.2835e-04
# Epoch 30/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 8.3394e-04
# Epoch 31/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 8.0944e-04
# Epoch 32/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.9850e-04
# Epoch 33/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.8492e-04
# Epoch 34/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.8309e-04
# Epoch 35/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.9380e-04
# Epoch 36/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.7467e-04
# Epoch 37/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 8.0614e-04
# Epoch 38/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.9486e-04
# Epoch 39/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.7194e-04
# Epoch 40/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.3478e-04
# Epoch 41/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.3173e-04
# Epoch 42/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.2373e-04
# Epoch 43/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.2612e-04
# Epoch 44/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 7.0000e-04
# Epoch 45/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.9096e-04
# Epoch 46/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.8226e-04
# Epoch 47/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.7200e-04
# Epoch 48/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.6720e-04
# Epoch 49/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.5910e-04
# Epoch 50/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.5210e-04
# Epoch 51/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.7764e-04
# Epoch 52/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.7192e-04
# Epoch 53/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.5537e-04
# Epoch 54/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.2710e-04
# Epoch 55/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.2007e-04
# Epoch 56/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.3836e-04
# Epoch 57/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.3233e-04
# Epoch 58/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.0632e-04
# Epoch 59/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.0715e-04
# Epoch 60/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 5.9110e-04
# Epoch 61/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 5.8605e-04
# Epoch 62/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 5.7807e-04
# Epoch 63/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 6.0614e-04
# Epoch 64/64
# 1340/1340 [==============================] - 3s 2ms/step - loss: 5.7955e-04

# %% [markdown]
# #### Test set

# %%
inputs = pg[len(pg) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)
X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)

# %%
rms=np.sqrt(np.mean(np.power((valid-closing_price),2)))
rms
# Out:
# 1.2103684248112796

# %%
train = pg[:1400]
valid = pg[1400:]
valid['Predictions'] = closing_price
plt.figure(figsize=(16,8))
plt.plot(valid[['close','Predictions']]) # predictions over test set
plt.legend(['Real', 'Predicted'])
# Out:
# /Users/subhamgupta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
s = pg[len(pg) - 60:].values
s = s.reshape(-1,1)
s = scaler.transform(s)

# %%
s = np.reshape(s, (s.shape[1],s.shape[0],1))
closing_price = model.predict(s)
closing_price = scaler.inverse_transform(closing_price)
closing_price # next day closing price
# Out:
# array([[54.027336]], dtype=float32)
